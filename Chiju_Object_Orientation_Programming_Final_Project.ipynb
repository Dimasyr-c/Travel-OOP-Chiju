# %% [markdown]
# <a href="https://colab.research.google.com/github/Dimasyr-c/Travel-OOP-Chiju/blob/main/Chiju_Object_Orientation_Programming_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hii, Welcome to Chiju!")
print("Kami adalah Platform yang membawahi banyak agen untuk membantumu dalam merencanakan Petualanganmu!")
print("Sebelum melangkah lebih jauh, kenalan dulu yuk")
print("Chiju ingin tahu siapa namamu?")
nama = input()
print("Hai " + nama + ", Nice to meet u!")
print("Kami ingin tahu kamu remaja dengan tipe yang mana")
print("A : Shopping, Fashionable")
print("B : Foodies, Hunger")
print("C : History, Art")
print("Upper case yah!")

while True:
    tipe = input()
    if tipe in ["A", "B", "C"]:
        break
    else:
        print("Tipe yang kamu pilih tidak valid. Silakan pilih A, B, atau C.")

# Data dictionary untuk travel agent berdasarkan tipe
data_travel_agent = {
    "A": {
        "Tipe": "Anak Mall",
        "PT Gumilang Jaya": {
            "Kendaraan": "Mobil",
            "Hotel": "Luminor Hotel",
            "Konsumsi": "Breakfast",
            "Tour Guide": "Icha",
            "Budget": 500_000,
        },
        "Cv Senayan": {
            "Kendaraan": "Vespa",
            "Hotel": "Jatim Ex Hotel",
            "Konsumsi": "Breakfast",
            "Tour Guide": "Ayu",
            "Budget": 500_000
        },
        "PT PIK": {
            "Kendaraan": "Mobil",
            "Hotel": "Santika Hotel",
            "Konsumsi": "Dinner",
            "Tour Guide": "Ayu",
            "Budget": 500_000
        },
        "Cv Pondok Kelabu": {
            "Kendaraan": "Bus",
            "Hotel": "Pop Hotel",
            "Konsumsi": "Brunch",
            "Tour Guide": "Ayu",
            "Budget": 1_500_000
        },
        "PT Jaya Abadi": {
            "Kendaraan": "Kereta",
            "Hotel": "Roblox Hotel",
            "Konsumsi": "Brunch",
            "Tour Guide": "Angel",
            "Budget": 500_000
        },
        "Cv Kemana Ya": {
            "Kendaraan": "Motor",
            "Hotel": "Aesthetic Hotel",
            "Konsumsi": "Brunch",
            "Tour Guide": "Angel",
            "Budget": 500_000
        },
        "PT Bintang Bersinar": {
            "Kendaraan": "Bus",
            "Hotel": "Roblox Hotel",
            "Konsumsi": "Dinner",
            "Tour Guide": "Angel",
            "Budget": 1_500_000
        },
        "PT Karunia": {
            "Kendaraan": "Mobil",
            "Hotel": "Luminor Hotel",
            "Konsumsi": "Dinner",
            "Tour Guide": "Ela",
            "Budget": 500_000
        }
    },
    "B": {
        "Tipe": "Anak Kuliner",
        "PT Bintang Kejora Makmur": {
            "Kendaraan": "Motor",
            "Hotel": "Jatim Ex Hotel",
            "Konsumsi": "Dinner",
            "Tour Guide": "Ela",
            "Budget": 500_000
        },
        "Cv Mekar Jaya Abadi": {
            "Kendaraan": "Angkot",
            "Hotel": "Santika Hotel",
            "Konsumsi": "Dinner",
            "Tour Guide": "Ela",
            "Budget": 500_000
        },
        "PT Happy Agent": {
            "Kendaraan": "Gojek",
            "Hotel": "Pop Hotel",
            "Konsumsi": "Dinner",
            "Tour Guide": "Lutfi",
            "Budget": 500_000
        },
        "Cv Panji Gumilang Zaytun": {
            "Kendaraan": "Kereta",
            "Hotel": "Roblox Hotel",
            "Konsumsi": "Lunch",
            "Tour Guide": "Lutfi",
            "Budget": 500_000
        },
        "PT Abadi Jaya": {
            "Kendaraan": "Mobil",
            "Hotel": "Aesthetic Hotel",
            "Konsumsi": "Lunch",
            "Tour Guide": "Lutfi",
            "Budget": 500_000
        },
        "Cv Agent Sehat": {
            "Kendaraan": "Angkot",
            "Hotel": "Roblox Hotel",
            "Konsumsi": "Lunch",
            "Tour Guide": "Raihan",
            "Budget": 500_000
        },
        "PT Jaya Abadi": {
            "Kendaraan": "Bus",
            "Hotel": "Tulip Hotel",
            "Konsumsi": "Lunch",
            "Tour Guide": "Raihan",
            "Budget": 1_500_000
        },
        "Cv Kemana Ya": {
            "Kendaraan": "Feeder",
            "Hotel": "Arjuna Homestay",
            "Konsumsi": "Dinner",
            "Tour Guide": "Raihan",
            "Budget": 500_000
        }
    },
    "C": {
        "Tipe": "Anak Museum",
        "PT Bintang Bersinar": {
            "Kendaraan": "Angkot",
            "Hotel": "Resort Sayan",
            "Konsumsi": "Dinner",
            "Tour Guide": "Ayu",
            "Budget": 500_000
        },
        "PT Bintang Bersinar": {
            "Kendaraan": "Motor",
            "Hotel": "Resort Purnama",
            "Konsumsi": "Dinner",
            "Tour Guide": "Ayu",
            "Budget": 500_000
        },
        "PT Karunia": {
            "Kendaraan": "Mobil",
            "Hotel": "Resort Komang",
            "Konsumsi": "Dinner",
            "Tour Guide": "Ayu",
            "Budget": 500_000
        },
        "PT Cakrawala": {
            "Kendaraan": "Bus",
            "Hotel": "Jaya Homestay",
            "Konsumsi": "Breakfast",
            "Tour Guide": "Icha",
            "Budget": 1_500_000
        },
        "CV Good Travel": {
            "Kendaraan": "Kereta",
            "Hotel": "Melati Homestay",
            "Konsumsi": "Breakfast",
            "Tour Guide": "Icha",
            "Budget": 500_000
        },
        "PT Alam Sejuk": {
            "Kendaraan": "Angkot",
            "Hotel": "Bougenville Homestay",
            "Konsumsi": "Breakfast",
            "Tour Guide": "Icha",
            "Budget": 500_000
        },
        "Cv Tanggung Jaya": {
            "Kendaraan": "Feeder",
            "Hotel": "Westin Homestay",
            "Konsumsi": "Brunch",
            "Tour Guide": "Angel",
            "Budget": 1_000_000
        },
        "Cv Kopi Sedap": {
            "Kendaraan": "Motor",
            "Hotel": "Green Camp",
            "Konsumsi": "Brunch",
            "Tour Guide": "Angel",
            "Budget": 500_000
        }
    }
}

if tipe in data_travel_agent:
    print("Wah, Ternyata kamu tipe yang", data_travel_agent[tipe]["Tipe"], "banget nih")

    # Find the minimum and maximum budget values
    travel_agents = data_travel_agent[tipe]
    all_budgets = [info["Budget"] for agent, info in travel_agents.items() if agent != "Tipe"]
    min_budget = min(all_budgets)
    max_budget = max(all_budgets)
    print(f"Harga terendah yang dimiliki oleh data travel kami adalah: {min_budget:,} Rupiah")
    print(f"Harga tertinggi yang dimiliki oleh data travel kami adalah: {max_budget:,} Rupiah")

    # Input budget user
    while True:
        try:
            print("Kami ingin tahu budget yang kamu miliki (dalam Rupiah):")
            user_budget = int(input())

            if user_budget >= min_budget and user_budget <= max_budget:
                break
            else:
                print(f"Budget harus di antara {min_budget:,} dan {max_budget:,} Rupiah.")
        except ValueError:
            print("Input tidak valid. Masukkan angka dalam Rupiah (tanpa titik atau koma).")

    print("Kami merekomendasikan beberapa travel agent sesuai dengan budgetmu:")

    available_agents = []

    for agent, info in travel_agents.items():
        if agent != "Tipe" and info["Budget"] <= user_budget:
            available_agents.append(agent)
            print(agent + ":")
            print("===== Fasilitas Agent =====")
            print("  - Kendaraan:", info["Kendaraan"])
            print("  - Hotel:", info["Hotel"])
            print("  - Konsumsi:", info["Konsumsi"])
            print("  - Tour Guide:", info["Tour Guide"])
            print("  - Budget:", info["Budget"])
            print("===============================")

    if not available_agents:
        print("Maaf, tidak ada travel agent yang sesuai dengan budgetmu.")
    else:
        selected_agent = None
        while selected_agent not in available_agents:
            print("Silahkan pilih travel agent yang ingin kamu gunakan:")
            selected_agent = input()
        print("Satu langkah lagi untuk mewujudkan Perjalanan Impianmu")
        print("Silahkan Hubungi travel agent pilihan kamu ya!")
        print("Terima kasih! Kamu telah memilih travel agent", selected_agent)
        print("Terima Kasih telah memilih Chiju sebagai bagian dari Perjalananmu!")

else:
    print("Tipe yang kamu pilih tidak valid.")
# Out:
# Hii, Welcome to Chiju!
# Kami adalah Platform yang membawahi banyak agen untuk membantumu dalam merencanakan Petualanganmu!
# Sebelum melangkah lebih jauh, kenalan dulu yuk
# Chiju ingin tahu siapa namamu?
# Dimas
# Hai Dimas, Nice to meet u!
# Kami ingin tahu kamu remaja dengan tipe yang mana
# A : Shopping, Fashionable
# B : Foodies, Hunger
# C : History, Art
# Upper case yah!
# B
# Wah, Ternyata kamu tipe yang Anak Kuliner banget nih
# Harga terendah yang dimiliki oleh data travel kami adalah: 500,000 Rupiah
# Harga tertinggi yang dimiliki oleh data travel kami adalah: 1,500,000 Rupiah
# Kami ingin tahu budget yang kamu miliki (dalam Rupiah):
# 2000000
# Budget harus di antara 500,000 dan 1,500,000 Rupiah.
# Kami ingin tahu budget yang kamu miliki (dalam Rupiah):
# 750000
# Kami merekomendasikan beberapa travel agent sesuai dengan budgetmu:
# PT Bintang Kejora Makmur:
# ===== Fasilitas Agent =====
#   - Kendaraan: Motor
#   - Hotel: Jatim Ex Hotel
#   - Konsumsi: Dinner
# ...
